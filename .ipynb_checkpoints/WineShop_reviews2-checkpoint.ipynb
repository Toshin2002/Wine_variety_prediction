# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('OSX_DS_assignment.csv')

# %%
df_trail = df.filter(['review_description','price','winery','variety'], axis=1)
df_trail.head(10)
# Out:
#                                   review_description  price  \
# 0  Aromas include tropical fruit, broom, brimston...    NaN
# 1  This is ripe and fruity, a wine that is smooth...   15.0
# 2  Tart and snappy, the flavors of lime flesh and...   14.0
# 3  Pineapple rind, lemon pith and orange blossom ...   13.0
# 4  Much like the regular bottling from 2012, this...   65.0
# 5  This dry and restrained wine offers spice in p...   24.0
# 6  Savory dried thyme notes accent sunnier flavor...   12.0
# 7  This has great depth of flavor with its fresh ...   27.0
# 8  Soft, supple plum envelopes an oaky structure ...   19.0
# 9  This is a dry wine, very spicy, with a tight, ...   30.0
#
#                 winery             variety
# 0              Nicosia         White Blend
# 1  Quinta dos Avidagos      Portuguese Red
# 2            Rainstorm          Pinot Gris
# 3           St. Julian            Riesling
# 4         Sweet Cheeks          Pinot Noir
# 5             Trimbach      Gewürztraminer
# 6          Heinz Eifel      Gewürztraminer
# 7   Jean-Baptiste Adam          Pinot Gris
# 8   Kirkland Signature  Cabernet Sauvignon
# 9           Leon Beyer      Gewürztraminer

# %%
df_trail.isnull().sum()
# Out:
# review_description       0
# price                 6963
# winery                   0
# variety                  0
# dtype: int64

# %%
print(df_trail['winery'].value_counts())
print(df_trail['variety'].value_counts())
# Out:
# Testarossa               217
# Williams Selyem          203
# Louis Latour             199
# Georges Duboeuf          195
# Chateau Ste. Michelle    187
#                         ...
# Vignobles de Roany         1
# Werewolf                   1
# Beautiful Dream            1
# Ankida Ridge               1
# Penedo Borges              1
# Name: winery, Length: 14728, dtype: int64
# Pinot Noir                    13272
# Chardonnay                    11753
# Cabernet Sauvignon             9472
# Red Blend                      8946
# Bordeaux-style Red Blend       6915
# Riesling                       5189
# Sauvignon Blanc                4967
# Syrah                          4142
# Rosé                           3564
# Merlot                         3102
# Nebbiolo                       2804
# Zinfandel                      2714
# Sangiovese                     2707
# Malbec                         2652
# Portuguese Red                 2466
# White Blend                    2360
# Sparkling Blend                2153
# Tempranillo                    1810
# Rhône-style Red Blend          1471
# Pinot Gris                     1455
# Champagne Blend                1396
# Cabernet Franc                 1353
# Grüner Veltliner               1345
# Portuguese White               1159
# Bordeaux-style White Blend     1066
# Pinot Grigio                   1052
# Gamay                          1025
# Gewürztraminer                 1012
# Name: variety, dtype: int64

# %%
df_trail = df_trail[df_trail['price'].notna()]
df_trail.head(10)
# Out:
#                                    review_description  price  \
# 1   This is ripe and fruity, a wine that is smooth...   15.0
# 2   Tart and snappy, the flavors of lime flesh and...   14.0
# 3   Pineapple rind, lemon pith and orange blossom ...   13.0
# 4   Much like the regular bottling from 2012, this...   65.0
# 5   This dry and restrained wine offers spice in p...   24.0
# 6   Savory dried thyme notes accent sunnier flavor...   12.0
# 7   This has great depth of flavor with its fresh ...   27.0
# 8   Soft, supple plum envelopes an oaky structure ...   19.0
# 9   This is a dry wine, very spicy, with a tight, ...   30.0
# 10  Slightly reduced, this wine offers a chalky, t...   34.0
#
#                  winery             variety
# 1   Quinta dos Avidagos      Portuguese Red
# 2             Rainstorm          Pinot Gris
# 3            St. Julian            Riesling
# 4          Sweet Cheeks          Pinot Noir
# 5              Trimbach      Gewürztraminer
# 6           Heinz Eifel      Gewürztraminer
# 7    Jean-Baptiste Adam          Pinot Gris
# 8    Kirkland Signature  Cabernet Sauvignon
# 9            Leon Beyer      Gewürztraminer
# 10     Louis M. Martini  Cabernet Sauvignon

# %%
df_trail.describe()
# df_trail['price'].isna().sum()
# Out:
#               price
# count  96359.000000
# mean      36.781224
# std       42.867069
# min        4.000000
# 25%       18.000000
# 50%       27.000000
# 75%       45.000000
# max     3300.000000

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def preprocess_text(text):
    tokens = word_tokenize(text.lower())  # Tokenize the text
    filtered_tokens = [lemmatizer.lemmatize(token) for token in tokens if token.isalpha() and token not in stop_words]
    return ' '.join(filtered_tokens)

df_trail['review_description'] = df_trail['review_description'].apply(preprocess_text)
print(df_desc.head(10))
